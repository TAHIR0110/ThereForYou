# %% [markdown]
# ---
# ### Deepface Module => accuracy 97%
# ###9 emotions + dominant emotion + confidence percentage + multiple face expression at once
# ### all required info at once => Age,gender,race,emotion
# ---
# ###With GUI = 7 emotions
# ---
# ###CNN =Accuracy= 90%

# %% [markdown]
# deepface module

# %%
pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.3/97.3 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 4.1 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=fdc3137288145bb413c9b7b1cebd401820874cf445db3202a7f2dc175a17ab48
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
import cv2
import matplotlib.pyplot as plt
from deepface import DeepFace
# Out:
# 24-05-28 18:14:35 - Directory /root/.deepface created
# 24-05-28 18:14:35 - Directory /root/.deepface/weights created

# %%
img = cv2.imread('unknown.jpg')
plt.imshow(img[:, :, : : -1])
plt.show()


result = DeepFace.analyze(img, actions = ['emotion'])
print(result)
# Out:
# 24-05-28 18:14:40 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 25.7MB/s]
# [{'emotion': {'angry': 3.2111424952745438, 'disgust': 0.11296879965811968, 'fear': 38.662660121917725, 'happy': 0.10764878243207932, 'sad': 27.940204739570618, 'surprise': 0.02033170749200508, 'neutral': 29.945051670074463}, 'dominant_emotion': 'fear', 'region': {'x': 400, 'y': 216, 'w': 71, 'h': 71, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.94}]

# %%
objs = DeepFace.analyze(img_path = "unknown.jpg",
        actions = ['age', 'gender', 'race', 'emotion']
)

print(objs)
# Out:
# Action: emotion: 100%|██████████| 4/4 [00:03<00:00,  1.03it/s]
# [{'age': 34, 'region': {'x': 400, 'y': 216, 'w': 71, 'h': 71, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.94, 'gender': {'Woman': 0.0002235017973362119, 'Man': 99.99977350234985}, 'dominant_gender': 'Man', 'race': {'asian': 6.265413935162221e-08, 'indian': 6.368652143239136e-06, 'black': 4.272003399588966e-09, 'white': 99.83392951892966, 'middle eastern': 0.1363901816848137, 'latino hispanic': 0.029677322063313076}, 'dominant_race': 'white', 'emotion': {'angry': 3.2111424952745438, 'disgust': 0.11296879965811968, 'fear': 38.662660121917725, 'happy': 0.10764878243207932, 'sad': 27.940204739570618, 'surprise': 0.02033170749200508, 'neutral': 29.945051670074463}, 'dominant_emotion': 'fear'}]
